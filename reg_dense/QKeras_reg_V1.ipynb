# %% [markdown]
# # QKeras dense layer comparison

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import keras
import numpy as np
import time
import random

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Flatten, LSTM, GRU, SimpleRNN, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

from collections import deque


from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow import keras
from matplotlib import pyplot as plt
from IPython.display import clear_output

import qkeras
from qkeras import *

import hls4ml
import plotting
# Out:
# 2022-04-21 15:31:05.413110: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/sft.cern.ch/lcg/releases/gcc/9.2.0/x86_64-centos7/bin/:/inteltools/altera/21.1.0.169.pro/gcc/lib64:/inteltools/altera/21.1.0.169.pro/hls/host/linux64/lib
# 2022-04-21 15:31:05.413126: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /atlas/bonnet/hls4ml/hls4ml/hls4ml/hls4ml/converters/__init__.py:15: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!")

# %% [markdown]
# ## Data creation

# %%
#Creating a simple dataset using numpy

x = np.linspace(-1, 1, 1000)
y = np.sin(5*x)

x_val = np.linspace(-1, 1, 100)
y_val = np.sin(5*x_val)

x_test = np.linspace(-1, 1, 1000)
y_test = np.sin(5*x_test)

# %%
import os
print(os.environ['LD_LIBRARY_PATH'])
print('and\n', os.environ['PATH'])
# Out:
# /cvmfs/sft.cern.ch/lcg/releases/gcc/9.2.0/x86_64-centos7/bin/:/inteltools/altera/21.1.0.169.pro/gcc/lib64:/inteltools/altera/21.1.0.169.pro/hls/host/linux64/lib
# and
#  /cvmfs/sft.cern.ch/lcg/releases/gcc/9.2.0/x86_64-centos7/bin/:/inteltools/altera/21.1.0.169.pro/quartus/bin:/inteltools/altera/21.1.0.169.pro/gcc/bin:/inteltools/altera/21.1.0.169.pro/hls/bin:/inteltools/altera/21.1.0.169.pro/qsys/bin:/inteltools/altera/21.1.0.169.pro/quartus/bin:/inteltools/mentor/2018-19/RHELx86/QUESTA-CORE-PRIME_10.7c/questasim/linux_x86_64:/atlas/bonnet/miniconda3/envs/hls4ml-tutorial/bin:/atlas/bonnet/miniconda3/condabin:/usr/lib64/qt-3.3/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin

# %% [markdown]
# ## Settings

# %%
output = 1

def bit_lenghts(i):
    #To change to create models with different bits parameter by defining the smallest bit lenghts 
    #Example : bits 8 ==> (i+4)*4
    return (i+3)*2

integer = (2)

def bit_width(i): return {'bits': (i+3)*2, 'integer': integer, 'symmetric': 0, 'alpha':1}

nbr_epoch = 15

# %% [markdown]
# ## Classic network

# %%
checkpoint_filepath = '/atlas/bonnet/tmp/model_checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                                save_weights_only=True,
                                                                monitor='val_loss',
                                                                mode='min',
                                                                save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.00001, verbose=1)

d_model = Sequential()

d_model.add(Dense(10,input_dim= 1,activation='relu', name='dense'))
d_model.add(Dense(output, activation='linear', name='dense_1'))
d_model.compile(loss="mse", optimizer=Adam(lr=0.001))

d_model.summary()

d_model.fit(x, y, validation_data= (x_val,y_val), epochs=80, batch_size=10, callbacks=[reduce_lr,model_checkpoint_callback])

d_model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                20
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
#   1/100 [..............................] - ETA: 14s - loss: 0.4596
# /atlas/bonnet/miniconda3/envs/hls4ml-tutorial/lib/python3.7/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5541 - val_loss: 0.5265 - lr: 0.0010
# Epoch 2/80
# 100/100 [==============================] - 0s 779us/step - loss: 0.5043 - val_loss: 0.4890 - lr: 0.0010
# Epoch 3/80
# 100/100 [==============================] - 0s 768us/step - loss: 0.4725 - val_loss: 0.4606 - lr: 0.0010
# Epoch 4/80
# 100/100 [==============================] - 0s 773us/step - loss: 0.4480 - val_loss: 0.4378 - lr: 0.0010
# Epoch 5/80
# 100/100 [==============================] - 0s 786us/step - loss: 0.4269 - val_loss: 0.4173 - lr: 0.0010
# Epoch 6/80
# 100/100 [==============================] - 0s 760us/step - loss: 0.4078 - val_loss: 0.3979 - lr: 0.0010
# Epoch 7/80
# 100/100 [==============================] - 0s 870us/step - loss: 0.3899 - val_loss: 0.3795 - lr: 0.0010
# Epoch 8/80
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3721 - val_loss: 0.3617 - lr: 0.0010
# Epoch 9/80
# 100/100 [==============================] - 0s 778us/step - loss: 0.3544 - val_loss: 0.3434 - lr: 0.0010
# Epoch 10/80
# 100/100 [==============================] - 0s 787us/step - loss: 0.3367 - val_loss: 0.3251 - lr: 0.0010
# Epoch 11/80
# 100/100 [==============================] - 0s 801us/step - loss: 0.3175 - val_loss: 0.3055 - lr: 0.0010
# Epoch 12/80
# 100/100 [==============================] - 0s 823us/step - loss: 0.2974 - val_loss: 0.2852 - lr: 0.0010
# Epoch 13/80
# 100/100 [==============================] - 0s 771us/step - loss: 0.2769 - val_loss: 0.2641 - lr: 0.0010
# Epoch 14/80
# 100/100 [==============================] - 0s 811us/step - loss: 0.2557 - val_loss: 0.2425 - lr: 0.0010
# Epoch 15/80
# 100/100 [==============================] - 0s 799us/step - loss: 0.2338 - val_loss: 0.2212 - lr: 0.0010
# Epoch 16/80
# 100/100 [==============================] - 0s 784us/step - loss: 0.2125 - val_loss: 0.1999 - lr: 0.0010
# Epoch 17/80
# 100/100 [==============================] - 0s 921us/step - loss: 0.1915 - val_loss: 0.1800 - lr: 0.0010
# Epoch 18/80
# 100/100 [==============================] - 0s 764us/step - loss: 0.1713 - val_loss: 0.1600 - lr: 0.0010
# Epoch 19/80
# 100/100 [==============================] - 0s 774us/step - loss: 0.1521 - val_loss: 0.1421 - lr: 0.0010
# Epoch 20/80
# 100/100 [==============================] - 0s 769us/step - loss: 0.1343 - val_loss: 0.1248 - lr: 0.0010
# Epoch 21/80
# 100/100 [==============================] - 0s 775us/step - loss: 0.1177 - val_loss: 0.1086 - lr: 0.0010
# Epoch 22/80
# 100/100 [==============================] - 0s 752us/step - loss: 0.1026 - val_loss: 0.0942 - lr: 0.0010
# Epoch 23/80
# 100/100 [==============================] - 0s 801us/step - loss: 0.0887 - val_loss: 0.0813 - lr: 0.0010
# Epoch 24/80
# 100/100 [==============================] - 0s 789us/step - loss: 0.0764 - val_loss: 0.0700 - lr: 0.0010
# Epoch 25/80
# 100/100 [==============================] - 0s 767us/step - loss: 0.0654 - val_loss: 0.0611 - lr: 0.0010
# Epoch 26/80
# 100/100 [==============================] - 0s 867us/step - loss: 0.0565 - val_loss: 0.0515 - lr: 0.0010
# Epoch 27/80
# 100/100 [==============================] - 0s 907us/step - loss: 0.0479 - val_loss: 0.0442 - lr: 0.0010
# Epoch 28/80
# 100/100 [==============================] - 0s 825us/step - loss: 0.0411 - val_loss: 0.0376 - lr: 0.0010
# Epoch 29/80
# 100/100 [==============================] - 0s 789us/step - loss: 0.0351 - val_loss: 0.0325 - lr: 0.0010
# Epoch 30/80
# 100/100 [==============================] - 0s 753us/step - loss: 0.0301 - val_loss: 0.0280 - lr: 0.0010
# Epoch 31/80
# 100/100 [==============================] - 0s 788us/step - loss: 0.0260 - val_loss: 0.0244 - lr: 0.0010
# Epoch 32/80
# 100/100 [==============================] - 0s 783us/step - loss: 0.0227 - val_loss: 0.0215 - lr: 0.0010
# Epoch 33/80
# 100/100 [==============================] - 0s 764us/step - loss: 0.0200 - val_loss: 0.0197 - lr: 0.0010
# Epoch 34/80
# 100/100 [==============================] - 0s 783us/step - loss: 0.0178 - val_loss: 0.0177 - lr: 0.0010
# Epoch 35/80
# 100/100 [==============================] - 0s 814us/step - loss: 0.0161 - val_loss: 0.0162 - lr: 0.0010
# Epoch 36/80
# 100/100 [==============================] - 0s 790us/step - loss: 0.0148 - val_loss: 0.0149 - lr: 0.0010
# Epoch 37/80
# 100/100 [==============================] - 0s 906us/step - loss: 0.0138 - val_loss: 0.0142 - lr: 0.0010
# Epoch 38/80
# 100/100 [==============================] - 0s 777us/step - loss: 0.0130 - val_loss: 0.0137 - lr: 0.0010
# Epoch 39/80
# 100/100 [==============================] - 0s 772us/step - loss: 0.0125 - val_loss: 0.0130 - lr: 0.0010
# Epoch 40/80
# 100/100 [==============================] - 0s 782us/step - loss: 0.0118 - val_loss: 0.0127 - lr: 0.0010
# Epoch 41/80
# 100/100 [==============================] - 0s 792us/step - loss: 0.0117 - val_loss: 0.0123 - lr: 0.0010
# Epoch 42/80
# 100/100 [==============================] - 0s 933us/step - loss: 0.0112 - val_loss: 0.0121 - lr: 0.0010
# Epoch 43/80
# 100/100 [==============================] - 0s 640us/step - loss: 0.0111 - val_loss: 0.0134 - lr: 0.0010
# Epoch 44/80
# 100/100 [==============================] - 0s 601us/step - loss: 0.0110 - val_loss: 0.0131 - lr: 0.0010
# Epoch 45/80
# 100/100 [==============================] - 0s 794us/step - loss: 0.0110 - val_loss: 0.0119 - lr: 0.0010
# Epoch 46/80
# 100/100 [==============================] - 0s 800us/step - loss: 0.0111 - val_loss: 0.0118 - lr: 0.0010
# Epoch 47/80
# 100/100 [==============================] - 0s 776us/step - loss: 0.0108 - val_loss: 0.0115 - lr: 0.0010
# Epoch 48/80
# 100/100 [==============================] - 0s 611us/step - loss: 0.0105 - val_loss: 0.0116 - lr: 0.0010
# Epoch 49/80
# 100/100 [==============================] - 0s 608us/step - loss: 0.0104 - val_loss: 0.0116 - lr: 0.0010
# Epoch 50/80
# 100/100 [==============================] - 0s 771us/step - loss: 0.0105 - val_loss: 0.0114 - lr: 0.0010
# Epoch 51/80
# 100/100 [==============================] - 0s 924us/step - loss: 0.0102 - val_loss: 0.0113 - lr: 0.0010
# Epoch 52/80
# 100/100 [==============================] - 0s 774us/step - loss: 0.0103 - val_loss: 0.0113 - lr: 0.0010
# Epoch 53/80
# 100/100 [==============================] - 0s 631us/step - loss: 0.0104 - val_loss: 0.0113 - lr: 0.0010
# Epoch 54/80
# 100/100 [==============================] - 0s 610us/step - loss: 0.0103 - val_loss: 0.0113 - lr: 0.0010
# Epoch 55/80
# 100/100 [==============================] - 0s 592us/step - loss: 0.0103 - val_loss: 0.0119 - lr: 0.0010
# Epoch 56/80
#   1/100 [..............................] - ETA: 0s - loss: 0.0170
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 100/100 [==============================] - 0s 925us/step - loss: 0.0103 - val_loss: 0.0112 - lr: 0.0010
# Epoch 57/80
# 100/100 [==============================] - 0s 590us/step - loss: 0.0100 - val_loss: 0.0113 - lr: 5.0000e-04
# Epoch 58/80
# 100/100 [==============================] - 0s 772us/step - loss: 0.0098 - val_loss: 0.0110 - lr: 5.0000e-04
# Epoch 59/80
# 100/100 [==============================] - 0s 612us/step - loss: 0.0100 - val_loss: 0.0110 - lr: 5.0000e-04
# Epoch 60/80
# 100/100 [==============================] - 0s 763us/step - loss: 0.0098 - val_loss: 0.0110 - lr: 5.0000e-04
# Epoch 61/80
# 100/100 [==============================] - 0s 600us/step - loss: 0.0098 - val_loss: 0.0110 - lr: 5.0000e-04
# Epoch 62/80
# 100/100 [==============================] - 0s 609us/step - loss: 0.0099 - val_loss: 0.0111 - lr: 5.0000e-04
# Epoch 63/80
#   1/100 [..............................] - ETA: 0s - loss: 0.0102
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 100/100 [==============================] - 0s 623us/step - loss: 0.0098 - val_loss: 0.0110 - lr: 5.0000e-04
# Epoch 64/80
# 100/100 [==============================] - 0s 589us/step - loss: 0.0097 - val_loss: 0.0110 - lr: 2.5000e-04
# Epoch 65/80
# 100/100 [==============================] - 0s 762us/step - loss: 0.0096 - val_loss: 0.0110 - lr: 2.5000e-04
# Epoch 66/80
# 100/100 [==============================] - 0s 742us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 67/80
# 100/100 [==============================] - 0s 749us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 68/80
# 100/100 [==============================] - 0s 776us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 69/80
# 100/100 [==============================] - 0s 616us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 70/80
# 100/100 [==============================] - 0s 613us/step - loss: 0.0096 - val_loss: 0.0110 - lr: 2.5000e-04
# Epoch 71/80
# 100/100 [==============================] - 0s 761us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 72/80
#   1/100 [..............................] - ETA: 0s - loss: 0.0211
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 100/100 [==============================] - 0s 791us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 2.5000e-04
# Epoch 73/80
# 100/100 [==============================] - 0s 772us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 74/80
# 100/100 [==============================] - 0s 596us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 75/80
# 100/100 [==============================] - 0s 774us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 76/80
# 100/100 [==============================] - 0s 606us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 77/80
#   1/100 [..............................] - ETA: 0s - loss: 0.0204
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 100/100 [==============================] - 0s 612us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.2500e-04
# Epoch 78/80
# 100/100 [==============================] - 0s 595us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 6.2500e-05
# Epoch 79/80
# 100/100 [==============================] - 0s 600us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 6.2500e-05
# Epoch 80/80
# 100/100 [==============================] - 0s 753us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 6.2500e-05

# %% [markdown]
# ## Quantized network :

# %%
def quantized_model (bits, original_weights):
    qcheckpoint_filepath = '/atlas/bonnet/tmp/qmodel_checkpoint'
    qmodel_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=qcheckpoint_filepath,
                                                                    save_weights_only=True,
                                                                    monitor='val_loss',
                                                                    mode='min',
                                                                    save_best_only=True)


    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.00001, verbose=1)

    qd_model = Sequential()
    
    qd_model.add(QDense(10,
                        input_dim= 1,
                        activation='relu',   
                        kernel_quantizer=quantized_bits(**bits),
                        bias_quantizer=quantized_bits(**bits)))
    #qd_model.add(QActivation(activation=quantized_relu(bits=bits['bits'], integer = bits['integer']), name='relu1'))                   
    qd_model.add(QDense(output, 
                        activation='linear',
                        kernel_quantizer=quantized_bits(**bits),
                        bias_quantizer=quantized_bits(**bits)))
    #qd_model.add(QActivation(activation=quantized_bits(**bits), name='linear1'))
    qd_model.compile(loss="mse", optimizer=Adam(lr=0.0001))
    
    qd_model.summary()
    
    #using the weight from the classic network as a base
    qd_model.set_weights(original_weights.get_weights())
    qd_model.fit(x, y, validation_data= (x_val,y_val),epochs = nbr_epoch, callbacks=[qmodel_checkpoint_callback,reduce_lr])
    qd_model.load_weights(qcheckpoint_filepath)

    return qd_model

def model_saving (): 
    models =[]
    for i in range(9):
        bits_parameter = bit_width(i)
        models.append( quantized_model(bits_parameter, d_model))
        print( 'bit width ', bits_parameter)        
    return models
        
qmodels = model_saving()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_36 (QDense)         (None, 10)                20
#
#  q_dense_37 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.0173 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 959us/step - loss: 0.0163 - val_loss: 0.0173 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0167 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 936us/step - loss: 0.0161 - val_loss: 0.0173 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 939us/step - loss: 0.0163 - val_loss: 0.0167 - lr: 1.0000e-04
# Epoch 6/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0139 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 8/15
# 32/32 [==============================] - 0s 944us/step - loss: 0.0157 - val_loss: 0.0139 - lr: 1.0000e-04
# Epoch 9/15
# 32/32 [==============================] - 0s 953us/step - loss: 0.0144 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 10/15
# 32/32 [==============================] - 0s 966us/step - loss: 0.0145 - val_loss: 0.0291 - lr: 1.0000e-04
# Epoch 11/15
# 32/32 [==============================] - 0s 941us/step - loss: 0.0156 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 12/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0097
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 950us/step - loss: 0.0158 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 13/15
# 32/32 [==============================] - 0s 916us/step - loss: 0.0158 - val_loss: 0.0139 - lr: 5.0000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 932us/step - loss: 0.0168 - val_loss: 0.0146 - lr: 5.0000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 930us/step - loss: 0.0122 - val_loss: 0.0273 - lr: 5.0000e-05
# bit width  {'bits': 6, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_38 (QDense)         (None, 10)                20
#
#  q_dense_39 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0111 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 930us/step - loss: 0.0100 - val_loss: 0.0113 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 946us/step - loss: 0.0100 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 909us/step - loss: 0.0105 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 6/15
# 32/32 [==============================] - 0s 911us/step - loss: 0.0107 - val_loss: 0.0124 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 912us/step - loss: 0.0102 - val_loss: 0.0124 - lr: 1.0000e-04
# Epoch 8/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0114
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 919us/step - loss: 0.0102 - val_loss: 0.0146 - lr: 1.0000e-04
# Epoch 9/15
# 32/32 [==============================] - 0s 918us/step - loss: 0.0104 - val_loss: 0.0118 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 923us/step - loss: 0.0108 - val_loss: 0.0113 - lr: 5.0000e-05
# Epoch 11/15
# 32/32 [==============================] - 0s 915us/step - loss: 0.0107 - val_loss: 0.0114 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 919us/step - loss: 0.0108 - val_loss: 0.0146 - lr: 5.0000e-05
# Epoch 13/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0212
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 944us/step - loss: 0.0110 - val_loss: 0.0146 - lr: 5.0000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 916us/step - loss: 0.0112 - val_loss: 0.0121 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 909us/step - loss: 0.0105 - val_loss: 0.0146 - lr: 2.5000e-05
# bit width  {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_40 (QDense)         (None, 10)                20
#
#  q_dense_41 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 937us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 907us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 932us/step - loss: 0.0096 - val_loss: 0.0110 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0155
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 934us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 920us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 900us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 937us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 921us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0126
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 955us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 945us/step - loss: 0.0097 - val_loss: 0.0109 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 942us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 931us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 2.5000e-05
# bit width  {'bits': 10, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_42 (QDense)         (None, 10)                20
#
#  q_dense_43 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 925us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 922us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 911us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0114
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 948us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 966us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 963us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 970us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0079
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 975us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 963us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 947us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 967us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 12, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_44 (QDense)         (None, 10)                20
#
#  q_dense_45 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 1s 7ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 981us/step - loss: 0.0096 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 954us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 957us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0067
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 980us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 978us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 970us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0092
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 956us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 967us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 978us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 939us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 968us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 14, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_46 (QDense)         (None, 10)                20
#
#  q_dense_47 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 985us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 953us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 939us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0081
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 937us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 937us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 939us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0094
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 941us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 907us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 934us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 924us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 16, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_48 (QDense)         (None, 10)                20
#
#  q_dense_49 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 1s 6ms/step - loss: 0.0096 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 958us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 959us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0087
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 995us/step - loss: 0.0095 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 962us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 980us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 931us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0091
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 956us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 955us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 935us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 947us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 921us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 18, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_50 (QDense)         (None, 10)                20
#
#  q_dense_51 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 967us/step - loss: 0.0096 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0117
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 977us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 925us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 924us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 910us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 919us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0108
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 968us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 932us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 947us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 938us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 926us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 20, 'integer': 2, 'symmetric': 0, 'alpha': 1}
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_dense_52 (QDense)         (None, 10)                20
#
#  q_dense_53 (QDense)         (None, 1)                 11
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 2/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 3/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 4/15
# 32/32 [==============================] - 0s 970us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 5/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 6/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0170
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 7/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 8/15
# 32/32 [==============================] - 0s 984us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 9/15
# 32/32 [==============================] - 0s 961us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 10/15
# 32/32 [==============================] - 0s 957us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 11/15
#  1/32 [..............................] - ETA: 0s - loss: 0.0131
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 0s 981us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 5.0000e-05
# Epoch 12/15
# 32/32 [==============================] - 0s 939us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 13/15
# 32/32 [==============================] - 0s 934us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 14/15
# 32/32 [==============================] - 0s 971us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# Epoch 15/15
# 32/32 [==============================] - 0s 941us/step - loss: 0.0095 - val_loss: 0.0108 - lr: 2.5000e-05
# bit width  {'bits': 22, 'integer': 2, 'symmetric': 0, 'alpha': 1}

# %%
for i  in range (9):    
    print(quantized_bits(**bit_width(i)))
# Out:
# quantized_bits(6,2,0,alpha=1)
# quantized_bits(8,2,0,alpha=1)
# quantized_bits(10,2,0,alpha=1)
# quantized_bits(12,2,0,alpha=1)
# quantized_bits(14,2,0,alpha=1)
# quantized_bits(16,2,0,alpha=1)
# quantized_bits(18,2,0,alpha=1)
# quantized_bits(20,2,0,alpha=1)
# quantized_bits(22,2,0,alpha=1)

# %% [markdown]
# ## Normal network, Quantized weights

# %%
configu = d_model.get_config()
tmp_model = Sequential().from_config(configu)
tmp_models = []

print(configu)   

for i in range (9) :   
    tmp_model.set_weights([quantized_bits(**bit_width(i))(n) for n in qmodels[i].get_weights()])
    tmp_models.append(tmp_model)
# Out:
# {'name': 'sequential_22', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, 1), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'dense_input'}}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'batch_input_shape': (None, 1), 'dtype': 'float32', 'units': 10, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}

# %% [markdown]
# ## HLS CONVERSION of the Keras model, every layer

# %%
#HLS CONVERSION of the Keras model, every layer

closs = []
qcloss = []
qchloss = []
ptq_results = []

bit_scale = []
for i in range (9):
    conf = hls4ml.utils.config_from_keras_model( d_model, granularity='name')
    print(conf)
    conf['LayerName']['dense']['Precision']['weight'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense']['Precision']['bias'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense']['Precision']['result'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'

    conf['LayerName']['dense_relu']['Precision'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense_relu']['table_t'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'

    conf['LayerName']['dense_1']['Precision']['weight'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense_1']['Precision']['bias'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense_1']['Precision']['result'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    
    conf['LayerName']['dense_1_linear']['Precision'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense_1_linear']['table_t'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    print(conf)
        
    hls_model = hls4ml.converters.convert_from_keras_model(d_model,
                                                            hls_config=conf,
                                                            output_dir='models/hls_models',
                                                            part='1SG280HU2F50E2VG',
                                                            backend='Quartus')
    hls_model.compile()

    #y_qckeras = tmp_models[i].predict(x_test)
    y_qchls = hls_model.predict(x_test.reshape(x_test.shape[0],1))
    ptq_results.append(y_qchls)
    y_keras = d_model.predict(x_test)
    closs.append(mse(y_test, y_keras))
    #qcloss.append(mse(y_test, y_qckeras))
    qchloss.append(mse(y_test, y_qchls))
    bit_scale.append(bit_lenghts(i))
    plt.figure()
    #plt.plot(y_qckeras, '--', linewidth=2)
    plt.plot(y_qchls)
    plt.plot(y_test)    
    plt.legend(['keras+hls', 'keras'])
    plt.title(f'PTQ : bitwidths of ({bit_lenghts(i)},{integer},0,1)')
    plt.show()

plt.figure()
plt.plot(bit_scale, qchloss)
plt.xlabel('bits')
plt.ylabel('MSE')
plt.title(f'PTQ : bitwidths of (x,{integer},0,1), {nbr_epoch} epochs')

plt.show()

plt.show()
# Out:
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>', 'result': 'ap_fixed<6,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<6,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<6,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>', 'result': 'ap_fixed<6,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<6,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<6,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 430us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>', 'result': 'ap_fixed<8,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<8,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<8,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>', 'result': 'ap_fixed<8,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<8,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<8,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 422us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>', 'result': 'ap_fixed<10,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<10,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<10,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>', 'result': 'ap_fixed<10,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<10,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<10,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 421us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>', 'result': 'ap_fixed<12,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<12,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<12,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>', 'result': 'ap_fixed<12,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<12,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<12,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 477us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<14,3>', 'bias': 'ap_fixed<14,3>', 'result': 'ap_fixed<14,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<14,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<14,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<14,3>', 'bias': 'ap_fixed<14,3>', 'result': 'ap_fixed<14,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<14,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<14,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 435us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,3>', 'bias': 'ap_fixed<16,3>', 'result': 'ap_fixed<16,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<16,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,3>', 'bias': 'ap_fixed<16,3>', 'result': 'ap_fixed<16,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<16,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 412us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<18,3>', 'bias': 'ap_fixed<18,3>', 'result': 'ap_fixed<18,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<18,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<18,3>', 'bias': 'ap_fixed<18,3>', 'result': 'ap_fixed<18,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<18,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 427us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<20,3>', 'bias': 'ap_fixed<20,3>', 'result': 'ap_fixed<20,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<20,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<20,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<20,3>', 'bias': 'ap_fixed<20,3>', 'result': 'ap_fixed<20,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<20,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<20,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 448us/step
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<22,3>', 'bias': 'ap_fixed<22,3>', 'result': 'ap_fixed<22,3>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<22,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<22,3>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<22,3>', 'bias': 'ap_fixed<22,3>', 'result': 'ap_fixed<22,3>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<22,3>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<22,3>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 435us/step

# %% [markdown]
# ## HLS CONVERSION of the Keras model, only dense layer

# %%
#HLS CONVERSION of the Keras model, only dense layer


qcloss = []
qchloss = []
closs = []
ptq_results_2 = []

bit_scale = []
for i in range (9):
    conf = hls4ml.utils.config_from_keras_model(d_model, granularity='name')
    print (conf)

    conf['LayerName']['dense']['Precision']['weight'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense']['Precision']['bias'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'

    conf['LayerName']['dense_1']['Precision']['weight'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'
    conf['LayerName']['dense_1']['Precision']['bias'] = f'ap_fixed<{bit_lenghts(i)},{integer+1}>'

    print(conf)

    hls_model = hls4ml.converters.convert_from_keras_model(d_model,
                                                        hls_config=conf,
                                                        output_dir='models/hls_models',
                                                        part='1SG280HU2F50E2VG',
                                                        backend='Quartus')
    hls_model.compile()

    y_qckeras = tmp_models[i].predict(x_test)
    y_qchls = hls_model.predict(x_test.reshape(x_test.shape[0],1))
    ptq_results_2.append(y_qchls)
    y_keras = d_model.predict(x_test)
    print ('shape', np.shape(y_qckeras))
    closs.append(mse(y_test, y_keras))
    qcloss.append(mse(y_test, y_qckeras))
    qchloss.append(mse(y_test, y_qchls))
    bit_scale.append(bit_lenghts(i))
    plt.figure()
    #plt.subplot()
    #plt.plot(y_keras)
    plt.plot(y_qckeras)
    plt.plot(y_qchls)
    plt.plot(y_test)    
    plt.legend(['keras+qweights', 'keras+hls', 'keras'])
    plt.title(f'PTQ : bitwidths of ({bit_lenghts(i)},{integer},0,1)')
    plt.show()


plt.figure()
plt.plot(bit_scale, qchloss)
plt.xlabel('bits')
plt.ylabel('MSE')
plt.title(f'PTQ : bitwidths of (x,{integer},0,1), {nbr_epoch} epochs')

plt.show()
# Out:
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 463us/step
# 32/32 [==============================] - 0s 427us/step
# shape (1000, 1)
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 423us/step
# 32/32 [==============================] - 0s 466us/step
# shape (1000, 1)
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 431us/step
# 32/32 [==============================] - 0s 429us/step
# shape (1000, 1)
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: Input
# Layer name: dense, layer type: Dense
#   -> Activation (relu), layer name: dense
# Layer name: dense_1, layer type: Dense
#   -> Activation (linear), layer name: dense_1
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<16,6>', 'bias': 'ap_fixed<16,6>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'dense_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'dense': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_relu': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}, 'dense_1': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>', 'result': 'ap_fixed<16,6>'}, 'ReuseFactor': 1}, 'dense_1_linear': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'table_size': 1024, 'table_t': 'ap_fixed<18,8>'}}}
# Interpreting Sequential
# Topology:
# Layer name: dense_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: dense, layer type: Dense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24533/2666341908.py in <module>
#      25                                                         part='1SG280HU2F50E2VG',
#      26                                                         backend='Quartus')
# ---> 27     hls_model.compile()
#      28
#      29     y_qckeras = tmp_models[i].predict(x_test)
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/graph.py in compile(self)
#     564         Users should call this function if they want to use `predict` functionality for simulation.
#     565         """
# --> 566         self.write()
#     567
#     568         lib_name = self.config.backend.compile(self)
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/graph.py in write(self)
#     557         self.config.config['Stamp'] = _make_stamp()
#     558
# --> 559         self.config.backend.write(self)
#     560
#     561     def compile(self):
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/backends/fpga/fpga_backend.py in write(self, model)
#      55         """
#      56
# ---> 57         model.apply_flow(self.get_writer_flow())
#      58
#      59     def get_writer_flow(self):
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/graph.py in apply_flow(self, flow)
#     336     def apply_flow(self, flow):
#     337         applied_flows = {}
# --> 338         self._apply_sub_flow(flow, applied_flows)
#     339         self._applied_flows.append(applied_flows)
#     340
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/graph.py in _apply_sub_flow(self, flow_name, applied_flows)
#     349
#     350         if len(flow.optimizers) > 0:
# --> 351             applied_passes = optimize_model(self, flow.optimizers)
#     352         else:
#     353             applied_passes = []
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/optimizer/optimizer.py in optimize_model(model, passes)
#     184         for opt_name, opt in optimizers.items():
#     185             if isinstance(opt, ModelOptimizerPass) and opt_name not in applied_passes:
# --> 186                 res = opt.transform(model)
#     187                 if res:
#     188                     applied_passes.add(opt_name)
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/model/optimizer/optimizer.py in transform(self, model)
#      54
#      55     def transform(self, model):
# ---> 56         retval = self.transform_func(model)
#      57         return retval if retval is not None else False
#      58
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/backends/fpga/fpga_backend.py in write_hls(self, model)
#     350     @model_optimizer()
#     351     def write_hls(self, model):
# --> 352         self.writer.write_hls(model)
#     353         return True
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/writer/quartus_writer.py in write_hls(self, model)
#     797         self.write_activation_tables(model)
#     798         self.write_yml(model)
# --> 799         self.write_tar(model)
#     800         print('Done')
#
# ~/hls4ml/hls4ml/hls4ml/hls4ml/writer/quartus_writer.py in write_tar(self, model)
#     781
#     782         with tarfile.open(model.config.get_output_dir() + '.tar.gz', mode='w:gz') as archive:
# --> 783             archive.add(model.config.get_output_dir(), recursive=True)
#     784
#     785     def write_hls(self, model):
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/tarfile.py in add(self, name, arcname, recursive, filter)
#    1949                 for f in sorted(os.listdir(name)):
#    1950                     self.add(os.path.join(name, f), os.path.join(arcname, f),
# -> 1951                             recursive, filter=filter)
#    1952
#    1953         else:
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/tarfile.py in add(self, name, arcname, recursive, filter)
#    1949                 for f in sorted(os.listdir(name)):
#    1950                     self.add(os.path.join(name, f), os.path.join(arcname, f),
# -> 1951                             recursive, filter=filter)
#    1952
#    1953         else:
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/tarfile.py in add(self, name, arcname, recursive, filter)
#    1942         if tarinfo.isreg():
#    1943             with bltn_open(name, "rb") as f:
# -> 1944                 self.addfile(tarinfo, f)
#    1945
#    1946         elif tarinfo.isdir():
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/tarfile.py in addfile(self, tarinfo, fileobj)
#    1970         # If there's data to follow, append it.
#    1971         if fileobj is not None:
# -> 1972             copyfileobj(fileobj, self.fileobj, tarinfo.size, bufsize=bufsize)
#    1973             blocks, remainder = divmod(tarinfo.size, BLOCKSIZE)
#    1974             if remainder > 0:
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/tarfile.py in copyfileobj(src, dst, length, exception, bufsize)
#     248         if len(buf) < bufsize:
#     249             raise exception("unexpected end of data")
# --> 250         dst.write(buf)
#     251
#     252     if remainder != 0:
#
# ~/miniconda3/envs/hls4ml-tutorial/lib/python3.7/gzip.py in write(self, data)
#     273
#     274         if length > 0:
# --> 275             self.fileobj.write(self.compress.compress(data))
#     276             self.size += length
#     277             self.crc = zlib.crc32(data, self.crc)
#
# KeyboardInterrupt:

# %% [markdown]
# ## HLS CONVERSION of the QKeras model

# %%
####### quantized model 

qhloss = []
qloss = []
bit_scale = []
qat_results = []
for i in range (9):
    conf = hls4ml.utils.config_from_keras_model(qmodels[i], granularity='name')
    print(conf)

    hls_qmodel = hls4ml.converters.convert_from_keras_model(qmodels[i],
                                                        hls_config=conf,
                                                        output_dir='models/hls_models',
                                                        part='1SG280HU2F50E2VG',
                                                        backend='Quartus')
                                
    hls_qmodel.compile()

    y_qkeras = qmodels[i].predict(x_test)
    y_qhls = hls_qmodel.predict(x_test.reshape(x_test.shape[0],1))
    qat_results.append(y_qhls)
    y_keras = d_model.predict(x_test)
    qhloss.append(mse(y_test, y_qhls))
    qloss.append(mse(y_test, y_qkeras))
    bit_scale.append(bit_lenghts(i))
    plt.figure()
    plt.plot(y_qkeras, '--', linewidth=2)
    plt.plot(y_qhls)
    plt.plot(y_test)    
    plt.legend(['qkeras', 'qkeras+hls', 'keras'])
    plt.title(f'QAT : bitwidths of ({bit_lenghts(i)},{integer},0,1)')
    plt.show()


plt.figure()
plt.plot(bit_scale, qhloss)
plt.xlabel('bits')
plt.ylabel('MSE')
plt.title(f'QAT : bitwidths of (x,{integer},0,1) {nbr_epoch} epochs')

plt.show()
# Out:
# Interpreting Sequential
# Topology:
# Layer name: q_dense_36_input, layer type: Input
# Layer name: q_dense_36, layer type: QDense
# Layer name: q_dense_37, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_36_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_36': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>'}, 'ReuseFactor': 1}, 'q_dense_37': {'Precision': {'weight': 'ap_fixed<6,3>', 'bias': 'ap_fixed<6,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_36_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_36, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_37, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 473us/step
# 32/32 [==============================] - 0s 424us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_38_input, layer type: Input
# Layer name: q_dense_38, layer type: QDense
# Layer name: q_dense_39, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_38_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_38': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>'}, 'ReuseFactor': 1}, 'q_dense_39': {'Precision': {'weight': 'ap_fixed<8,3>', 'bias': 'ap_fixed<8,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_38_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_38, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_39, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 476us/step
# 32/32 [==============================] - 0s 421us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_40_input, layer type: Input
# Layer name: q_dense_40, layer type: QDense
# Layer name: q_dense_41, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_40_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_40': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>'}, 'ReuseFactor': 1}, 'q_dense_41': {'Precision': {'weight': 'ap_fixed<10,3>', 'bias': 'ap_fixed<10,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_40_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_40, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_41, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 490us/step
# 32/32 [==============================] - 0s 423us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_42_input, layer type: Input
# Layer name: q_dense_42, layer type: QDense
# Layer name: q_dense_43, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_42_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_42': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>'}, 'ReuseFactor': 1}, 'q_dense_43': {'Precision': {'weight': 'ap_fixed<12,3>', 'bias': 'ap_fixed<12,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_42_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_42, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_43, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 464us/step
# 32/32 [==============================] - 0s 414us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_44_input, layer type: Input
# Layer name: q_dense_44, layer type: QDense
# Layer name: q_dense_45, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_44_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_44': {'Precision': {'weight': 'ap_fixed<14,3>', 'bias': 'ap_fixed<14,3>'}, 'ReuseFactor': 1}, 'q_dense_45': {'Precision': {'weight': 'ap_fixed<14,3>', 'bias': 'ap_fixed<14,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_44_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_44, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_45, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 516us/step
# 32/32 [==============================] - 0s 440us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_46_input, layer type: Input
# Layer name: q_dense_46, layer type: QDense
# Layer name: q_dense_47, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_46_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_46': {'Precision': {'weight': 'ap_fixed<16,3>', 'bias': 'ap_fixed<16,3>'}, 'ReuseFactor': 1}, 'q_dense_47': {'Precision': {'weight': 'ap_fixed<16,3>', 'bias': 'ap_fixed<16,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_46_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_46, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_47, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 446us/step
# 32/32 [==============================] - 0s 401us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_48_input, layer type: Input
# Layer name: q_dense_48, layer type: QDense
# Layer name: q_dense_49, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_48_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_48': {'Precision': {'weight': 'ap_fixed<18,3>', 'bias': 'ap_fixed<18,3>'}, 'ReuseFactor': 1}, 'q_dense_49': {'Precision': {'weight': 'ap_fixed<18,3>', 'bias': 'ap_fixed<18,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_48_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_48, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_49, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 472us/step
# 32/32 [==============================] - 0s 450us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_50_input, layer type: Input
# Layer name: q_dense_50, layer type: QDense
# Layer name: q_dense_51, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_50_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_50': {'Precision': {'weight': 'ap_fixed<20,3>', 'bias': 'ap_fixed<20,3>'}, 'ReuseFactor': 1}, 'q_dense_51': {'Precision': {'weight': 'ap_fixed<20,3>', 'bias': 'ap_fixed<20,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_50_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_50, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_51, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 457us/step
# 32/32 [==============================] - 0s 410us/step
# Interpreting Sequential
# Topology:
# Layer name: q_dense_52_input, layer type: Input
# Layer name: q_dense_52, layer type: QDense
# Layer name: q_dense_53, layer type: QDense
# {'Model': {'Precision': 'ap_fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency'}, 'LayerName': {'q_dense_52_input': {'Precision': {'result': 'ap_fixed<16,6>'}}, 'q_dense_52': {'Precision': {'weight': 'ap_fixed<22,3>', 'bias': 'ap_fixed<22,3>'}, 'ReuseFactor': 1}, 'q_dense_53': {'Precision': {'weight': 'ap_fixed<22,3>', 'bias': 'ap_fixed<22,3>'}, 'ReuseFactor': 1}}}
# Interpreting Sequential
# Topology:
# Layer name: q_dense_52_input, layer type: InputLayer, input shapes: [[None, 1]], output shape: [None, 1]
# Layer name: q_dense_52, layer type: QDense, input shapes: [[None, 1]], output shape: [None, 10]
# Layer name: q_dense_53, layer type: QDense, input shapes: [[None, 10]], output shape: [None, 1]
# Creating HLS model
# Writing HLS project
# Done
# 32/32 [==============================] - 0s 479us/step
# 32/32 [==============================] - 0s 434us/step

# %% [markdown]
# ## Results

# %%
plt.figure()
plt.plot(bit_scale, closs)
plt.plot(bit_scale, qloss, 'r+')
plt.plot(bit_scale, qchloss)

plt.plot(bit_scale, qhloss)   
plt.legend(['keras','qkeras','PQT : keras+hls',  'QAT : qkeras+hls'])
plt.yscale("log")
plt.xlabel('bits')
plt.ylabel('MSE')
plt.title(f'bitwidths of (x,{integer},0,1) {nbr_epoch} epochs')

plt.show()

plt.figure()
plt.plot(bit_scale, closs)
plt.plot(bit_scale, qloss, 'r+')
plt.plot(bit_scale, qchloss)

plt.plot(bit_scale, qhloss)   
plt.legend(['keras','qkeras','PQT : keras+hls',  'QAT : qkeras+hls'])
plt.xlabel('bits')
plt.ylabel('MSE')
plt.title(f'bitwidths of (x,{integer},0,1) {nbr_epoch} epochs')

plt.show()

# %%
for q, p, p2 in zip (qat_results, ptq_results, ptq_result_2):
    plt.plot(y)
    plt.plot(p)
    plt.plot(q)
    plt.plot(p2)

    plt.legend(['true','PTQ','QAT','PTQ2'])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24533/3103584416.py in <module>
# ----> 1 for q, p, p2 in zip (qat_results, ptq_results, ptq_result_2):
#       2     plt.plot(y)
#       3     plt.plot(p)
#       4     plt.plot(q)
#       5     plt.plot(p2)
#
# NameError: name 'ptq_result_2' is not defined

# %%
for q, p in zip (qat_results, ptq_results):
    plt.plot(y)
    plt.plot(p)
    plt.plot(q)
    plt.legend(['true','PTQ','QAT'])
    plt.show()

# %% [markdown]
# ## Analyse of the weights

# %%
plt.hist(np.concatenate([i.flatten() for i in d_model.get_weights()]))
# Out:
# (array([1., 3., 8., 2., 8., 7., 1., 0., 0., 1.]),
#  array([-2.4798443 , -1.9255514 , -1.3712585 , -0.8169656 , -0.26267266,
#          0.29162025,  0.8459132 ,  1.4002061 ,  1.954499  ,  2.508792  ,
#          3.0630848 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
for qm in qmodels:
    plt.hist(np.concatenate([i.flatten() for i in qm.get_weights()]))
    plt.show()
