# %% [markdown]
# # QKeras RNN comparison

# %% [markdown]
# 1. Create a model and compare its performance to the boosted model
# 2. If the model outreach the performance of the boosted model :
#  -   create a model with the same feature with qkeras (QAT) and
#  -   quantized the keras model (PTQ)
# 3. Compare those two to PTQ boosted model

# %% [markdown]
# The models with keras should converge to around 1e-5 or 9.8e-6
#
# For QKeras it's been somewhere around 1.1e-5 or so

# %% [markdown]
# # To Run Everytime

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import keras
import numpy as np
import time
import random
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Flatten, LSTM, GRU, SimpleRNN, Conv2D, MaxPooling2D, Flatten, Dropout, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

from collections import deque


from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow import keras
from matplotlib import pyplot as plt
from IPython.display import clear_output

import qkeras
from qkeras import *

import hls4ml
import nnlar
from nnlar.datashaper import DataShaper
# Out:
# 2022-05-11 11:54:14.454569: I tensorflow/core/util/util.cc:168] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-05-11 11:54:14.460503: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-11 11:54:14.460524: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# name convert optimizers ['fuse_bias_add', 'remove_useless_transpose', 'output_rounding_saturation_mode', 'qkeras_factorize_alpha', 'extract_ternary_threshold', 'fuse_consecutive_batch_normalization'] File: flow.py Line: 23
# ...

# %%
# Load libraries if they are changed
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data creation

# %%
from nnlar.datashaper import DataShaper
ds = DataShaper.from_h5("../data/rdgap_mu140.h5")

x, x_val, x_test, y, y_val, y_test = ds()
# Out:
# shapes (1999995, 5, 1) (1999995, 1)
# shapes (899992, 5, 1) (99995, 5, 1) (999998, 5, 1)

# %%
boosted_model =  tf.keras.models.load_model('pb_file')

boosted_model.summary()
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2022-05-11 11:54:20.256294: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-11 11:54:20.256324: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-11 11:54:20.256348: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (martop): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# ## Settings

# %%
# settings of the networks 
output = 1

nbr_batch = 40

nbr_epoch = 500
lr=0.001

nbr_conv_epoch1 = 4 #number of epochs for the conversion 
nbr_conv_epoch2 = 8 #number of epochs for the conversion 
nbr_conv_epoch3 = 12 #number of epochs for the conversion 



def units(j): return (j+2)*2
units_range = 5

# %%
#quantized settings
integer = 3


def bit_lenghts(i):
    #To change to create models with different bits parameter by defining the smallest bit lenghts 
    #Example : bits 8 ==> (i+4)*4
    return (i+2)*2

def bit_width(i): return {'bits': (i+2)*2, 'integer': integer, 'symmetric': 0, 'alpha':1}

bits_range = 5

# %%
# path

#path of the tested models 
def models_path(j) : return f"tests/models_test/epochs={nbr_epoch}/models_units={units(j)}_batch={nbr_batch}_lr={lr}.h5"

#path of the qconverted models
def qmodels_path1(j, i): return f"tests/qmodels_test/qconverted/qmodels_units={units(j)}_epoch={nbr_conv_epoch1}_batch={nbr_batch}_lr={lr},<{bit_lenghts(i)},{integer}>.h5"
def qmodels_path2(j, i): return f"tests/qmodels_test/qconverted/qmodels_units={units(j)}_epoch={nbr_conv_epoch2}_batch={nbr_batch}_lr={lr},<{bit_lenghts(i)},{integer}>.h5"
def qmodels_path3(j, i): return f"tests/qmodels_test/qconverted/qmodels_units={units(j)}_epoch={nbr_conv_epoch3}_batch={nbr_batch}_lr={lr},<{bit_lenghts(i)},{integer}>.h5"


#path of the qtrained models
def qtrained_models_path(j, i): return f"tests/qmodels_test/qtrained/qmodels_units={units(j)}_epoch={nbr_epoch}_batch={nbr_batch}_lr={lr},<{bit_lenghts(i)},{integer}>.h5"

#path of the qref models 
def qrefmodels_path1 (i) : return f"qmodels_epoch={nbr_conv_epoch1}/qmodels<{bit_lenghts(i)},{integer}>.h5"
def qrefmodels_path2 (i) : return f"qmodels_epoch={nbr_conv_epoch1}/qmodels<{bit_lenghts(i)},{integer}>.h5"

# %% [markdown]
# # 3. Compare the results

# %%
bit_nbr = []
loss1 = [] 
loss2 = []
loss3 = []
loss4 = []
loss5 = []
loss6 = []
unit_nbr = []

for i in range(bits_range):
    qmodel3 = qkeras.utils.load_qmodel(qrefmodels_path1 (i))        
    y_qkeras3 = qmodel3.predict(x_test)
    qmodel4 = qkeras.utils.load_qmodel(qrefmodels_path2 (i))        
    y_qkeras4 = qmodel4.predict(x_test)    
    bit_nbr.append(bit_lenghts(i))
    for j in range (units_range):

        unit_nbr.append(f'{units(j)}')
        qmodel1 = qkeras.utils.load_qmodel(qmodels_path1(j,i))        
        y_qkeras1 = qmodel1.predict(x_test)
        qmodel2 = qkeras.utils.load_qmodel(qmodels_path2(j,i))        
        y_qkeras2 = qmodel2.predict(x_test)        
        qmodel5 = qkeras.utils.load_qmodel(qmodels_path3(j,i))        
        y_qkeras5 = qmodel5.predict(x_test)
        qmodel6 = qkeras.utils.load_qmodel(qtrained_models_path(j,i))        
        y_qkeras6 = qmodel6.predict(x_test)


        loss1.append(mse(y_test,y_qkeras1))        
        loss2.append(mse(y_test,y_qkeras2))
        loss3.append(mse(y_test,y_qkeras3))
        loss4.append(mse(y_test,y_qkeras4))        
        loss5.append(mse(y_test,y_qkeras5))
        loss6.append(mse(y_test,y_qkeras6))

    
    plt.figure(figsize=(20,14))
    plt.plot(loss1)
    plt.plot(loss2)
    plt.plot(loss5)
    plt.plot(loss6)
    plt.plot(loss3)
    plt.plot(loss4)
    plt.legend(['4 epochs','8 epochs','12 epochs','qtrained ref','4  epochs ref', '8  epochs ref'])
    plt.xticks(np.arange(len(unit_nbr)), [f"{unit}" for unit in unit_nbr])
    
    plt.axvspan(0, 5, facecolor='red', alpha=0.5)
    plt.text(1.75, 0.002, "<4,3>", fontsize = 20 )
    plt.text(6.75, 0.002, "<6,3>", fontsize = 20 )
    plt.text(11.75, 0.002, "<8,3>", fontsize = 20 )
    plt.text(16.75, 0.002, "<10,3>", fontsize = 20 )
    plt.text(21.75, 0.002, "<12,3>", fontsize = 20 )
   
    
    plt.axvspan(5, 10, facecolor='darkorange', alpha=0.5)
    plt.axvspan(10, 15, facecolor='gold', alpha=0.5)
    plt.axvspan(15, 20, facecolor='greenyellow', alpha=0.5)    
    plt.axvspan(20, 25, facecolor='turquoise', alpha=0.5)
 
  
    plt.xlabel('units settings')
    plt.yscale('log')
    plt.ylabel('MSE')
    plt.title(f'MSE qkeras x units, comparison with differente bitwidth, integer={integer} \n network used :  lr={lr}')
    plt.show()
# Out:
# ...
# 31250/31250 [==============================] - 46s 1ms/step

# %%
    plt.figure(figsize=(20,14))
    plt.plot(loss1)
    plt.plot(loss2)
    plt.plot(loss5)
    plt.plot(loss6)
    plt.plot(loss3)
    plt.plot(loss4)
    plt.legend(['4 epochs','8 epochs','12 epochs','qtrained ref','4  epochs ref', '8  epochs ref'])
    plt.xticks(np.arange(len(unit_nbr)), [f"{unit}" for unit in unit_nbr])
    
    plt.axvspan(0, 5, facecolor='red', alpha=0.5)
    plt.text(1.75, 0.002, "<4,3>", fontsize = 20 )
    plt.text(6.75, 0.002, "<6,3>", fontsize = 20 )
    plt.text(11.75, 0.002, "<8,3>", fontsize = 20 )
    plt.text(16.75, 0.002, "<10,3>", fontsize = 20 )
    plt.text(21.75, 0.002, "<12,3>", fontsize = 20 )
   
    
    plt.axvspan(5, 10, facecolor='darkorange', alpha=0.5)
    plt.axvspan(10, 15, facecolor='gold', alpha=0.5)
    plt.axvspan(15, 20, facecolor='greenyellow', alpha=0.5)    
    plt.axvspan(20, 25, facecolor='turquoise', alpha=0.5)
 
  
    plt.xlabel('units settings')
    plt.yscale('log')
    plt.ylabel('MSE')
    plt.title(f'MSE qkeras x units, comparison with differente bitwidth, integer={integer} \n network used :  lr={lr}')
    plt.show()

# %%
bit_nbr = []
loss3 = []
loss4 = []
unit_nbr = []

for i in range(bits_range):
        qmodel4 = qkeras.utils.load_qmodel(f'qmodels_epoch=4/qmodels_units,<{bit_lenghts(i)},3>.h5')        
        y_qkeras4 = qmodel4.predict(x_test)
        for j in range(units_range):
                qmodel3 = qkeras.utils.load_qmodel(qmodels_path3(j,i))        
                y_qkeras3 = qmodel3.predict(x_test)                        

                loss3.append(mse(y_test,y_qkeras3))
                loss4.append(mse(y_test,y_qkeras4))

                plt.figure()
                plt.hist(y_test-y_qkeras4, bins=20)
                plt.yscale('log')
                plt.title(f' y_test - y_qkeras(units={units(j)})')
                plt.show()
# Out:
# ...
# 31250/31250 [==============================] - 48s 2ms/step
